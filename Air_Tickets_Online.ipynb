# %%
while True:
  command = input("Press 's' to start: ")     ##if condition satifies i.e. when command input is 's', it enters loop
  if (command.lower() == 's'):      #doesn't matter if 's' wriitten as 's' or 'S' because .lower() makes the input lowercase
    departure_destination = input('Enter Departure Destination (dhaka): ')  #departure location is to be given as input. For this program, 'dhaka' only.
    if (departure_destination.lower() == "dhaka"):  #only if 'dhaka' is given input then it will proceeed to next condition
      arrival_destination = input('Enter Arrival Destination (new york/london/japan ): ') #asking for input from 3 arrival destination

      if (arrival_destination.lower() == "new york"): #if destination is 'new york' only, then it will get under its condition
        print('''
Please select class (1/2/3):
(1)First Class - $150
(2)Business Class - $120
(3)Economy Class - $80
''')       #it will show class as soon as arrival destination is given input
        select_class = int(input())   #there are 3 options and user will give input as integer. If the value is not 1/2/3 then the program will restart
        if (select_class == 1):  #only if class is given input '1' then it will enter this condition
          no_of_passengers = int(input('Enter Number Of Passengers: '))  #the user can give input any integer number here since passenger can not a float
          total = 150 * no_of_passengers   #it will make the price of that class by multiplying fee with number of passenger
          print('Total cost:$', total)   #the result of the total cost will be printed here

          confirm_ticket = input('''
Press "y" to confirm ticket
Press "c" to cancel ticket
Press "r" to restart process
''')            #the user get to make decision of either confirm, cancel or rstart the whole ticket process after this line
          if (confirm_ticket.lower() == 'y'):  #when user type 'y' as input, program will enter this condition
            print('''
Thank you for your purchase.
Have a great day!
''')
            break     #after confirming ticket, the user's work is done. So the program will get out of loop by 'break'
          elif (confirm_ticket.lower() == 'c'): #when user type 'c' as input, program will enter this condition
            print('''
Your purchase has been cancelled.
''')
            break
          elif (confirm_ticket.lower() == 'r'):
            print(f'Starting Again')   #when user press 'r', the program through looping, will start the program again from first
          else:             #when the user input anything other than y/c/r, program will restart from first
            print('Invalid Input. Please start again.')

        elif (select_class == 2):   #when user input '2', it will enter this condition and follows same process as earlier
          no_of_passengers = int(input('Enter Number Of Passengers: '))
          total = 120 * no_of_passengers
          print('Total cost:$', total)

          confirm_ticket = input('''
Press "y" to confirm ticket
Press "c" to cancel ticket
Press "r" to restart process
''')

          if (confirm_ticket.lower() == 'y'):
            print('''
Thank you for your purchase.
Have a great day!
''')
            break
          elif (confirm_ticket.lower() == 'c'):
            print('''
Your purchase has been cancelled.
''')
            break
          elif (confirm_ticket.lower() == 'r'):
            print(f'Starting Again')
          else:
            print('Invalid Input. Please start again.')

        elif (select_class == 3):    #same as when class == '1' expect for input values are different
          no_of_passengers = int(input('Enter Number Of Passengers: '))
          total = 80 * no_of_passengers
          print('Total cost:$', total)

          confirm_ticket = input('''
Press "y" to confirm ticket
Press "c" to cancel ticket
Press "r" to restart process
''')

          if (confirm_ticket.lower() == 'y'):
            print('''
Thank you for your purchase.
Have a great day!
''')
            break
          elif (confirm_ticket.lower() == 'c'):
            print('''
Your purchase has been cancelled.
''')
            break
          elif (confirm_ticket.lower() == 'r'):
            print(f'Starting Again')
          else:
            print('Invalid Input. Please start again.')



      elif (arrival_destination.lower() == "london"):   #follows same process as 'new york' but class prices are different
        print('''
Please select class (1/2/3):
(1)First Class - $100
(2)Business Class - $80
(3)Economy Class - $50
''')
        select_class = int(input())
        if (select_class == 1):
          no_of_passengers = int(input('Enter Number Of Passengers: '))
          total = 100 * no_of_passengers
          print('Total cost:$', total)

          confirm_ticket = input('''
Press "y" to confirm ticket
Press "c" to cancel ticket
Press "r" to restart process
''')
          if (confirm_ticket.lower() == 'y'):
            print('''
Thank you for your purchase.
Have a great day!
''')
            break
          elif (confirm_ticket.lower() == 'c'):
            print('''
Your purchase has been cancelled.
''')
            break
          elif (confirm_ticket.lower() == 'r'):
            print(f'Starting Again')
          else:
            print('Invalid Input. Please start again.')

        elif (select_class == 2):
          no_of_passengers = int(input('Enter Number Of Passengers: '))
          total = 80 * no_of_passengers
          print('Total cost:$', total)

          confirm_ticket = input('''
Press "y" to confirm ticket
Press "c" to cancel ticket
Press "r" to restart process
''')

          if (confirm_ticket.lower() == 'y'):
            print('''
Thank you for your purchase.
Have a great day!
''')
            break
          elif (confirm_ticket.lower() == 'c'):
            print('''
Your purchase has been cancelled.
''')
            break
          elif (confirm_ticket.lower() == 'r'):
            print(f'Starting Again')
          else:
            print('Invalid Input. Please start again.')

        elif (select_class == 3):
          no_of_passengers = int(input('Enter Number Of Passengers: '))
          total = 50 * no_of_passengers
          print('Total cost:$', total)

          confirm_ticket = input('''
Press "y" to confirm ticket
Press "c" to cancel ticket
Press "r" to restart process
''')

          if (confirm_ticket.lower() == 'y'):
            print('''
Thank you for your purchase.
Have a great day!
''')
            break
          elif (confirm_ticket.lower() == 'c'):
            print('''
Your purchase has been cancelled.
''')
            break
          elif (confirm_ticket.lower() == 'r'):
            print(f'Starting Again')
          else:
            print('Invalid Input. Please start again.')


      if (arrival_destination.lower() == "japan"):  #follows same process as 'new york' but class prices are different
        print('''
Please select class (1/2/3):
(1)First Class - $80
(2)Business Class - $50
(3)Economy Class - $30
''')
        select_class = int(input())
        if (select_class == 1):
          no_of_passengers = int(input('Enter Number Of Passengers: '))
          total = 80 * no_of_passengers
          print('Total cost:$', total)

          confirm_ticket = input('''
Press "y" to confirm ticket
Press "c" to cancel ticket
Press "r" to restart process
''')
          if (confirm_ticket.lower() == 'y'):
            print('''
Thank you for your purchase.
Have a great day!
''')
            break
          elif (confirm_ticket.lower() == 'c'):
            print('''
Your purchase has been cancelled.
''')
            break
          elif (confirm_ticket.lower() == 'r'):
            print(f'Starting Again')
          else:
            print('Invalid Input. Please start again.')

        elif (select_class == 2):
          no_of_passengers = int(input('Enter Number Of Passengers: '))
          total = 50 * no_of_passengers
          print('Total cost:$', total)

          confirm_ticket = input('''
Press "y" to confirm ticket
Press "c" to cancel ticket
Press "r" to restart process
''')

          if (confirm_ticket.lower() == 'y'):
            print('''
Thank you for your purchase.
Have a great day!
''')
            break
          elif (confirm_ticket.lower() == 'c'):
            print('''
Your purchase has been cancelled.
''')
            break
          elif (confirm_ticket.lower() == 'r'):
            print(f'Starting Again')
          else:
            print('Invalid Input. Please start again.')

        elif (select_class == 3):
          no_of_passengers = int(input('Enter Number Of Passengers: '))
          total = 30 * no_of_passengers
          print('Total cost:$', total)

          confirm_ticket = input('''
Press "y" to confirm ticket
Press "c" to cancel ticket
Press "r" to restart process
''')

          if (confirm_ticket.lower() == 'y'):
            print('''
Thank you for your purchase.
Have a great day!
''')
            break
          elif (confirm_ticket.lower() == 'c'):
            print('''
Your purchase has been cancelled.
''')
            break
          elif (confirm_ticket.lower() == 'r'):
            print(f'Starting Again')
          else:
            print('Invalid Input. Please start again.')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-0a2be9002c14> in <cell line: 1>()
#       1 while True:
# ----> 2   command = input("Press 's' to start: ")     ##if condition satifies i.e. when command input is 's', it enters loop
#       3   if (command.lower() == 's'):      #doesn't matter if 's' wriitten as 's' or 'S' because .lower() makes the input lowercase
#       4     departure_destination = input('Enter Departure Destination (dhaka): ')  #departure location is to be given as input. For this program, 'dhaka' only.
#       5     if (departure_destination.lower() == "dhaka"):  #only if 'dhaka' is given input then it will proceeed to next condition
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
# ...
